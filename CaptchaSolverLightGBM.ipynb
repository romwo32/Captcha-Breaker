# %%
import os
import cv2
import numpy as np
import lightgbm as lgb
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

# Bildpfade und Labels einlesen
image_paths = []
labels = []
base_folder_path = "ImgCaptchaDiffFonts"

for filename in os.listdir(base_folder_path):
    if filename.endswith(".jpg"):
        image_paths.append(os.path.join(base_folder_path, filename))
        labels.append(filename.split('.')[0])

# Bilder Abschnitte teilen
def split_image(image, n_splits=5):
    h, w = image.shape
    split_width = w // n_splits
    sections = [image[:, i*split_width:(i+1)*split_width] for i in range(n_splits)]
    return sections

X = []
y = []
for path, label in zip(image_paths, labels):
    img = preprocess_image(path)
    sections = split_image(img)
    for i, section in enumerate(sections):
        X.append(section.flatten())
        y.append(label[i])  # Einzelne Zeichen als Labels

X = np.array(X)
y = np.array(y)

# Labels numerisch kodieren
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Daten in Trainings- und Testsätze aufteilen
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)

# %%
def preprocess_image(image_path, target_size=(270, 50)):
    img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    img = cv2.resize(img, target_size)
    
    # Adaptive Schwellenwert-Binarisierung anwenden
    img = cv2.adaptiveThreshold(img, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 11, 2)

    # Alle nicht-weißen Pixel schwarz machen
    img[img < 255] = 0

    # Invertiere die Farben, um schwarze Pixelgruppen zu identifizieren
    inverted = cv2.bitwise_not(img)

    # Verbundene Komponenten finden
    num_labels, labels, stats, _ = cv2.connectedComponentsWithStats(inverted, connectivity=8)

    # Entferne Pixelgruppen, die kleiner als 20 Pixel sind
    for i in range(1, num_labels):
        if stats[i, cv2.CC_STAT_AREA] < 20:
            inverted[labels == i] = 0

    # Invertiere die Farben zurück, sodass schwarze Pixel auf weißem Hintergrund sind
    result = cv2.bitwise_not(inverted)

    return result

# Beispielbilder anzeigen
max_images_per_row = 5
num_images_to_display = min(len(image_paths), 10)

fig, axes = plt.subplots(num_images_to_display, max_images_per_row + 1, figsize=(15, num_images_to_display * 3))

for i in range(num_images_to_display):
    image_path = image_paths[i]
    original_img = plt.imread(image_path)  # Originalbild einlesen
    img = preprocess_image(image_path)  # Bild verarbeiten
    sections = split_image(img)
    
    # Originalbild anzeigen
    axes[i, 0].imshow(original_img, cmap='gray')  # Originalbild anzeigen
    axes[i, 0].set_title(f'Original: {labels[i]}')
    axes[i, 0].axis('off')
    
    # Aufgeteilte Abschnitte anzeigen
    for j, section in enumerate(sections):
        if j < max_images_per_row:  # Begrenze die Anzahl der angezeigten Abschnitte pro Zeile
            axes[i, j+1].imshow(section, cmap='gray')
            axes[i, j+1].set_title(f'Section {j+1}')
            axes[i, j+1].axis('off')

plt.tight_layout()
plt.show()

# %%
import lightgbm as lgb
from flaml import AutoML
from sklearn.model_selection import train_test_split
import numpy as np
import matplotlib.pyplot as plt

# Bereite die Daten vor
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)

# Initialisiere AutoML
automl = AutoML()

# Setze die Konfigurationsparameter für AutoML
automl_settings = {
    "time_budget": 1000,  # Erhöhtes Zeitbudget in Sekunden
    "metric": 'accuracy',  # Metrik zur Optimierung
    "task": 'classification',  # Art der Aufgabe
    "log_file_name": 'lightgbm_automl.log',  # Log-Datei
    "estimator_list": ['lgbm', 'rf', 'xgboost'],  # Verwende verschiedene Schätzer
    "n_splits": 5,  # Cross-Validation
    "ensemble": True,  # Ensembling aktivieren
    "verbose": 3  # Verbalisiere die Fortschritte
}

# Trainiere das Modell mit FLAML
automl.fit(X_train=X_train, y_train=y_train, **automl_settings)

# Beste Hyperparameter aus FLAML
best_params = automl.best_config

# Anpassung der Hyperparameter für LightGBM zur Vermeidung von Overfitting
params = {
    "objective": "multiclass",
    "num_class": len(np.unique(y_encoded)),
    "metric": "multi_logloss",
    "verbose": -1,
    "learning_rate": 0.01,  # Niedrigere Lernrate
    "num_leaves": best_params.get('num_leaves', 31),
    "min_data_in_leaf": best_params.get('min_data_in_leaf', 20),
    "bagging_fraction": best_params.get('bagging_fraction', 0.8),  # Bootstrap-Sampling
    "bagging_freq": best_params.get('bagging_freq', 1),  # Frequenz für Bagging
    "feature_fraction": best_params.get('feature_fraction', 0.8),
    "lambda_l1": best_params.get('lambda_l1', 0.1),
    "lambda_l2": best_params.get('lambda_l2', 0.1)
}

# Trainings- und Validierungsdaten vorbereiten
train_data = lgb.Dataset(X_train, label=y_train)
validation_data = lgb.Dataset(X_test, label=y_test, reference=train_data)

# Modell trainieren mit Callbacks für Early Stopping
evals_result = {}
callbacks = [lgb.early_stopping(stopping_rounds=10), lgb.record_evaluation(evals_result)]

model = lgb.train(
    params,
    train_data,
    valid_sets=[train_data, validation_data],
    num_boost_round=3000,
    callbacks=callbacks
)

# Vorhersagen auf dem Testsatz
y_pred = model.predict(X_test, num_iteration=model.best_iteration)
y_pred = [np.argmax(line) for line in y_pred]

# Lernkurve visualisieren
def plot_training_metrics(evals_result):
    plt.figure(figsize=(10, 6))
    plt.plot(evals_result['training']['multi_logloss'], label='Training Log Loss')
    plt.plot(evals_result['valid_1']['multi_logloss'], label='Validation Log Loss')
    plt.xlabel('Iterations')
    plt.ylabel('Log Loss')
    plt.title('Training and Validation Log Loss')
    plt.legend()
    plt.show()

plot_training_metrics(evals_result)

# Vorhersagen auf dem Testsatz für Einzelzeichen
y_pred = model.predict(X_test, num_iteration=model.best_iteration)
y_pred = [np.argmax(line) for line in y_pred]

# Rücktransformation der Vorhersagen in die ursprünglichen Zeichen
y_pred_decoded = label_encoder.inverse_transform(y_pred)
y_test_decoded = label_encoder.inverse_transform(y_test)
# Out:
# [flaml.automl.logger: 02-11 14:55:56] {1728} INFO - task = classification
# [flaml.automl.logger: 02-11 14:55:56] {1739} INFO - Evaluation method: holdout
# [flaml.automl.logger: 02-11 14:55:56] {1838} INFO - Minimizing error metric: 1-accuracy
# [flaml.automl.logger: 02-11 14:55:56] {1955} INFO - List of ML learners in AutoML Run: ['lgbm', 'rf', 'xgboost']
# [flaml.automl.logger: 02-11 14:55:56] {2258} INFO - iteration 0, current learner lgbm
# [flaml.automl.logger: 02-11 14:55:58] {2393} INFO - Estimated sufficient time budget=24492s. Estimated necessary time budget=24s.
# [flaml.automl.logger: 02-11 14:55:58] {2442} INFO -  at 2.5s,	estimator lgbm's best error=0.9388,	best estimator lgbm's best error=0.9388
# [flaml.automl.logger: 02-11 14:55:58] {2258} INFO - iteration 1, current learner lgbm
# [flaml.automl.logger: 02-11 14:56:01] {2442} INFO -  at 5.0s,	estimator lgbm's best error=0.9388,	best estimator lgbm's best error=0.9388
# [flaml.automl.logger: 02-11 14:56:01] {2258} INFO - iteration 2, current learner lgbm
# [flaml.automl.logger: 02-11 14:56:03] {2442} INFO -  at 7.5s,	estimator lgbm's best error=0.9363,	best estimator lgbm's best error=0.9363
# [flaml.automl.logger: 02-11 14:56:03] {2258} INFO - iteration 3, current learner xgboost
# [flaml.automl.logger: 02-11 14:56:05] {2442} INFO -  at 9.4s,	estimator xgboost's best error=0.9402,	best estimator lgbm's best error=0.9363
# [flaml.automl.logger: 02-11 14:56:05] {2258} INFO - iteration 4, current learner lgbm
# [flaml.automl.logger: 02-11 14:56:08] {2442} INFO -  at 12.0s,	estimator lgbm's best error=0.9304,	best estimator lgbm's best error=0.9304
# [flaml.automl.logger: 02-11 14:56:08] {2258} INFO - iteration 5, current learner lgbm
# [flaml.automl.logger: 02-11 14:56:10] {2442} INFO -  at 14.5s,	estimator lgbm's best error=0.9304,	best estimator lgbm's best error=0.9304
# [flaml.automl.logger: 02-11 14:56:10] {2258} INFO - iteration 6, current learner lgbm
# [flaml.automl.logger: 02-11 14:56:13] {2442} INFO -  at 17.4s,	estimator lgbm's best error=0.9304,	best estimator lgbm's best error=0.9304
# [flaml.automl.logger: 02-11 14:56:13] {2258} INFO - iteration 7, current learner lgbm
# [flaml.automl.logger: 02-11 14:56:16] {2442} INFO -  at 20.1s,	estimator lgbm's best error=0.9167,	best estimator lgbm's best error=0.9167
# [flaml.automl.logger: 02-11 14:56:16] {2258} INFO - iteration 8, current learner lgbm
# [flaml.automl.logger: 02-11 14:56:18] {2442} INFO -  at 22.7s,	estimator lgbm's best error=0.9167,	best estimator lgbm's best error=0.9167
# [flaml.automl.logger: 02-11 14:56:18] {2258} INFO - iteration 9, current learner xgboost
# [flaml.automl.logger: 02-11 14:56:20] {2442} INFO -  at 24.8s,	estimator xgboost's best error=0.9402,	best estimator lgbm's best error=0.9167
# [flaml.automl.logger: 02-11 14:56:20] {2258} INFO - iteration 10, current learner xgboost
# [flaml.automl.logger: 02-11 14:56:22] {2442} INFO -  at 26.8s,	estimator xgboost's best error=0.9378,	best estimator lgbm's best error=0.9167
# [flaml.automl.logger: 02-11 14:56:22] {2258} INFO - iteration 11, current learner xgboost
# [flaml.automl.logger: 02-11 14:56:24] {2442} INFO -  at 28.8s,	estimator xgboost's best error=0.9378,	best estimator lgbm's best error=0.9167
# [flaml.automl.logger: 02-11 14:56:24] {2258} INFO - iteration 12, current learner xgboost
# [flaml.automl.logger: 02-11 14:56:27] {2442} INFO -  at 31.2s,	estimator xgboost's best error=0.9314,	best estimator lgbm's best error=0.9167
# [flaml.automl.logger: 02-11 14:56:27] {2258} INFO - iteration 13, current learner xgboost
# [flaml.automl.logger: 02-11 14:56:29] {2442} INFO -  at 33.7s,	estimator xgboost's best error=0.9221,	best estimator lgbm's best error=0.9167
# [flaml.automl.logger: 02-11 14:56:29] {2258} INFO - iteration 14, current learner lgbm
# [flaml.automl.logger: 02-11 14:56:33] {2442} INFO -  at 37.3s,	estimator lgbm's best error=0.8829,	best estimator lgbm's best error=0.8829
# [flaml.automl.logger: 02-11 14:56:33] {2258} INFO - iteration 15, current learner xgboost
# [flaml.automl.logger: 02-11 14:56:38] {2442} INFO -  at 42.6s,	estimator xgboost's best error=0.9167,	best estimator lgbm's best error=0.8829
# [flaml.automl.logger: 02-11 14:56:38] {2258} INFO - iteration 16, current learner rf
# [flaml.automl.logger: 02-11 14:56:38] {2442} INFO -  at 42.9s,	estimator rf's best error=0.9593,	best estimator lgbm's best error=0.8829
# [flaml.automl.logger: 02-11 14:56:38] {2258} INFO - iteration 17, current learner lgbm
# [flaml.automl.logger: 02-11 14:56:41] {2442} INFO -  at 45.6s,	estimator lgbm's best error=0.8829,	best estimator lgbm's best error=0.8829
# [flaml.automl.logger: 02-11 14:56:41] {2258} INFO - iteration 18, current learner rf
# [flaml.automl.logger: 02-11 14:56:41] {2442} INFO -  at 45.9s,	estimator rf's best error=0.9510,	best estimator lgbm's best error=0.8829
# [flaml.automl.logger: 02-11 14:56:41] {2258} INFO - iteration 19, current learner rf
# [flaml.automl.logger: 02-11 14:56:42] {2442} INFO -  at 46.1s,	estimator rf's best error=0.9510,	best estimator lgbm's best error=0.8829
# [flaml.automl.logger: 02-11 14:56:42] {2258} INFO - iteration 20, current learner rf
# [flaml.automl.logger: 02-11 14:56:42] {2442} INFO -  at 46.6s,	estimator rf's best error=0.9422,	best estimator lgbm's best error=0.8829
# [flaml.automl.logger: 02-11 14:56:42] {2258} INFO - iteration 21, current learner rf
# [flaml.automl.logger: 02-11 14:56:43] {2442} INFO -  at 47.0s,	estimator rf's best error=0.9422,	best estimator lgbm's best error=0.8829
# [flaml.automl.logger: 02-11 14:56:43] {2258} INFO - iteration 22, current learner rf
# [flaml.automl.logger: 02-11 14:56:43] {2442} INFO -  at 47.4s,	estimator rf's best error=0.9422,	best estimator lgbm's best error=0.8829
# [flaml.automl.logger: 02-11 14:56:43] {2258} INFO - iteration 23, current learner rf
# [flaml.automl.logger: 02-11 14:56:43] {2442} INFO -  at 47.7s,	estimator rf's best error=0.9422,	best estimator lgbm's best error=0.8829
# [flaml.automl.logger: 02-11 14:56:43] {2258} INFO - iteration 24, current learner xgboost
# [flaml.automl.logger: 02-11 14:56:52] {2442} INFO -  at 56.2s,	estimator xgboost's best error=0.9054,	best estimator lgbm's best error=0.8829
# [flaml.automl.logger: 02-11 14:56:52] {2258} INFO - iteration 25, current learner rf
# [flaml.automl.logger: 02-11 14:56:52] {2442} INFO -  at 56.7s,	estimator rf's best error=0.9309,	best estimator lgbm's best error=0.8829
# [flaml.automl.logger: 02-11 14:56:52] {2258} INFO - iteration 26, current learner rf
# [flaml.automl.logger: 02-11 14:56:53] {2442} INFO -  at 57.2s,	estimator rf's best error=0.9309,	best estimator lgbm's best error=0.8829
# [flaml.automl.logger: 02-11 14:56:53] {2258} INFO - iteration 27, current learner xgboost
# [flaml.automl.logger: 02-11 14:56:58] {2442} INFO -  at 62.3s,	estimator xgboost's best error=0.9054,	best estimator lgbm's best error=0.8829
# [flaml.automl.logger: 02-11 14:56:58] {2258} INFO - iteration 28, current learner xgboost
# [flaml.automl.logger: 02-11 14:57:10] {2442} INFO -  at 74.6s,	estimator xgboost's best error=0.8172,	best estimator xgboost's best error=0.8172
# [flaml.automl.logger: 02-11 14:57:10] {2258} INFO - iteration 29, current learner lgbm
# [flaml.automl.logger: 02-11 14:57:20] {2442} INFO -  at 84.4s,	estimator lgbm's best error=0.6497,	best estimator lgbm's best error=0.6497
# [flaml.automl.logger: 02-11 14:57:20] {2258} INFO - iteration 30, current learner lgbm
# [flaml.automl.logger: 02-11 14:57:31] {2442} INFO -  at 95.5s,	estimator lgbm's best error=0.6497,	best estimator lgbm's best error=0.6497
# [flaml.automl.logger: 02-11 14:57:31] {2258} INFO - iteration 31, current learner rf
# [flaml.automl.logger: 02-11 14:57:32] {2442} INFO -  at 96.0s,	estimator rf's best error=0.9309,	best estimator lgbm's best error=0.6497
# [flaml.automl.logger: 02-11 14:57:32] {2258} INFO - iteration 32, current learner rf
# [flaml.automl.logger: 02-11 14:57:32] {2442} INFO -  at 96.7s,	estimator rf's best error=0.8711,	best estimator lgbm's best error=0.6497
# [flaml.automl.logger: 02-11 14:57:32] {2258} INFO - iteration 33, current learner lgbm
# [flaml.automl.logger: 02-11 14:57:40] {2442} INFO -  at 104.4s,	estimator lgbm's best error=0.6497,	best estimator lgbm's best error=0.6497
# [flaml.automl.logger: 02-11 14:57:40] {2258} INFO - iteration 34, current learner rf
# [flaml.automl.logger: 02-11 14:57:40] {2442} INFO -  at 104.9s,	estimator rf's best error=0.8711,	best estimator lgbm's best error=0.6497
# [flaml.automl.logger: 02-11 14:57:40] {2258} INFO - iteration 35, current learner xgboost
# [flaml.automl.logger: 02-11 14:57:48] {2442} INFO -  at 112.7s,	estimator xgboost's best error=0.8172,	best estimator lgbm's best error=0.6497
# [flaml.automl.logger: 02-11 14:57:48] {2258} INFO - iteration 36, current learner rf
# [flaml.automl.logger: 02-11 14:57:49] {2442} INFO -  at 113.6s,	estimator rf's best error=0.8354,	best estimator lgbm's best error=0.6497
# [flaml.automl.logger: 02-11 14:57:49] {2258} INFO - iteration 37, current learner rf
# [flaml.automl.logger: 02-11 14:57:50] {2442} INFO -  at 114.4s,	estimator rf's best error=0.8354,	best estimator lgbm's best error=0.6497
# [flaml.automl.logger: 02-11 14:57:50] {2258} INFO - iteration 38, current learner rf
# [flaml.automl.logger: 02-11 14:57:51] {2442} INFO -  at 115.6s,	estimator rf's best error=0.8354,	best estimator lgbm's best error=0.6497
# [flaml.automl.logger: 02-11 14:57:51] {2258} INFO - iteration 39, current learner rf
# [flaml.automl.logger: 02-11 14:57:52] {2442} INFO -  at 116.7s,	estimator rf's best error=0.7722,	best estimator lgbm's best error=0.6497
# [flaml.automl.logger: 02-11 14:57:52] {2258} INFO - iteration 40, current learner rf
# [flaml.automl.logger: 02-11 14:57:53] {2442} INFO -  at 117.6s,	estimator rf's best error=0.7722,	best estimator lgbm's best error=0.6497
# [flaml.automl.logger: 02-11 14:57:53] {2258} INFO - iteration 41, current learner lgbm
# [flaml.automl.logger: 02-11 14:58:00] {2442} INFO -  at 124.5s,	estimator lgbm's best error=0.6497,	best estimator lgbm's best error=0.6497
# [flaml.automl.logger: 02-11 14:58:00] {2258} INFO - iteration 42, current learner rf
# [flaml.automl.logger: 02-11 14:58:01] {2442} INFO -  at 125.2s,	estimator rf's best error=0.7722,	best estimator lgbm's best error=0.6497
# [flaml.automl.logger: 02-11 14:58:01] {2258} INFO - iteration 43, current learner xgboost
# [flaml.automl.logger: 02-11 14:58:07] {2442} INFO -  at 131.7s,	estimator xgboost's best error=0.8172,	best estimator lgbm's best error=0.6497
# [flaml.automl.logger: 02-11 14:58:07] {2258} INFO - iteration 44, current learner rf
# [flaml.automl.logger: 02-11 14:58:09] {2442} INFO -  at 133.6s,	estimator rf's best error=0.7722,	best estimator lgbm's best error=0.6497
# [flaml.automl.logger: 02-11 14:58:09] {2258} INFO - iteration 45, current learner rf
# [flaml.automl.logger: 02-11 14:58:11] {2442} INFO -  at 135.5s,	estimator rf's best error=0.7511,	best estimator lgbm's best error=0.6497
# [flaml.automl.logger: 02-11 14:58:11] {2258} INFO - iteration 46, current learner rf
# [flaml.automl.logger: 02-11 14:58:12] {2442} INFO -  at 136.5s,	estimator rf's best error=0.7511,	best estimator lgbm's best error=0.6497
# [flaml.automl.logger: 02-11 14:58:12] {2258} INFO - iteration 47, current learner lgbm
# [flaml.automl.logger: 02-11 14:58:28] {2442} INFO -  at 152.1s,	estimator lgbm's best error=0.5919,	best estimator lgbm's best error=0.5919
# [flaml.automl.logger: 02-11 14:58:28] {2258} INFO - iteration 48, current learner rf
# [flaml.automl.logger: 02-11 14:58:30] {2442} INFO -  at 154.2s,	estimator rf's best error=0.7423,	best estimator lgbm's best error=0.5919
# [flaml.automl.logger: 02-11 14:58:30] {2258} INFO - iteration 49, current learner xgboost
# [flaml.automl.logger: 02-11 14:58:55] {2442} INFO -  at 179.0s,	estimator xgboost's best error=0.7585,	best estimator lgbm's best error=0.5919
# [flaml.automl.logger: 02-11 14:58:55] {2258} INFO - iteration 50, current learner rf
# [flaml.automl.logger: 02-11 14:58:56] {2442} INFO -  at 180.6s,	estimator rf's best error=0.7423,	best estimator lgbm's best error=0.5919
# [flaml.automl.logger: 02-11 14:58:56] {2258} INFO - iteration 51, current learner rf
# [flaml.automl.logger: 02-11 14:58:58] {2442} INFO -  at 182.8s,	estimator rf's best error=0.7423,	best estimator lgbm's best error=0.5919
# [flaml.automl.logger: 02-11 14:58:58] {2258} INFO - iteration 52, current learner rf
# [flaml.automl.logger: 02-11 14:59:00] {2442} INFO -  at 184.7s,	estimator rf's best error=0.7423,	best estimator lgbm's best error=0.5919
# [flaml.automl.logger: 02-11 14:59:00] {2258} INFO - iteration 53, current learner lgbm
# [flaml.automl.logger: 02-11 14:59:22] {2442} INFO -  at 206.2s,	estimator lgbm's best error=0.5919,	best estimator lgbm's best error=0.5919
# [flaml.automl.logger: 02-11 14:59:22] {2258} INFO - iteration 54, current learner rf
# [flaml.automl.logger: 02-11 14:59:23] {2442} INFO -  at 207.7s,	estimator rf's best error=0.7403,	best estimator lgbm's best error=0.5919
# [flaml.automl.logger: 02-11 14:59:23] {2258} INFO - iteration 55, current learner rf
# [flaml.automl.logger: 02-11 14:59:25] {2442} INFO -  at 209.5s,	estimator rf's best error=0.7403,	best estimator lgbm's best error=0.5919
# [flaml.automl.logger: 02-11 14:59:25] {2258} INFO - iteration 56, current learner rf
# [flaml.automl.logger: 02-11 14:59:27] {2442} INFO -  at 211.6s,	estimator rf's best error=0.7403,	best estimator lgbm's best error=0.5919
# [flaml.automl.logger: 02-11 14:59:27] {2258} INFO - iteration 57, current learner rf
# [flaml.automl.logger: 02-11 14:59:28] {2442} INFO -  at 212.7s,	estimator rf's best error=0.7403,	best estimator lgbm's best error=0.5919
# [flaml.automl.logger: 02-11 14:59:28] {2258} INFO - iteration 58, current learner lgbm
# [flaml.automl.logger: 02-11 14:59:37] {2442} INFO -  at 221.3s,	estimator lgbm's best error=0.5919,	best estimator lgbm's best error=0.5919
# [flaml.automl.logger: 02-11 14:59:37] {2258} INFO - iteration 59, current learner rf
# [flaml.automl.logger: 02-11 14:59:39] {2442} INFO -  at 223.3s,	estimator rf's best error=0.7403,	best estimator lgbm's best error=0.5919
# [flaml.automl.logger: 02-11 14:59:39] {2258} INFO - iteration 60, current learner rf
# [flaml.automl.logger: 02-11 14:59:40] {2442} INFO -  at 224.3s,	estimator rf's best error=0.7403,	best estimator lgbm's best error=0.5919
# [flaml.automl.logger: 02-11 14:59:40] {2258} INFO - iteration 61, current learner rf
# [flaml.automl.logger: 02-11 14:59:42] {2442} INFO -  at 226.8s,	estimator rf's best error=0.7403,	best estimator lgbm's best error=0.5919
# [flaml.automl.logger: 02-11 14:59:42] {2258} INFO - iteration 62, current learner rf
# [flaml.automl.logger: 02-11 14:59:43] {2442} INFO -  at 227.7s,	estimator rf's best error=0.7403,	best estimator lgbm's best error=0.5919
# [flaml.automl.logger: 02-11 14:59:43] {2258} INFO - iteration 63, current learner lgbm
# [flaml.automl.logger: 02-11 15:00:06] {2442} INFO -  at 250.4s,	estimator lgbm's best error=0.5919,	best estimator lgbm's best error=0.5919
# [flaml.automl.logger: 02-11 15:00:06] {2258} INFO - iteration 64, current learner rf
# [flaml.automl.logger: 02-11 15:00:08] {2442} INFO -  at 252.2s,	estimator rf's best error=0.7403,	best estimator lgbm's best error=0.5919
# [flaml.automl.logger: 02-11 15:00:08] {2258} INFO - iteration 65, current learner rf
# [flaml.automl.logger: 02-11 15:00:09] {2442} INFO -  at 253.5s,	estimator rf's best error=0.6796,	best estimator lgbm's best error=0.5919
# [flaml.automl.logger: 02-11 15:00:09] {2258} INFO - iteration 66, current learner rf
# [flaml.automl.logger: 02-11 15:00:12] {2442} INFO -  at 256.8s,	estimator rf's best error=0.6369,	best estimator lgbm's best error=0.5919
# [flaml.automl.logger: 02-11 15:00:12] {2258} INFO - iteration 67, current learner lgbm
# [flaml.automl.logger: 02-11 15:00:23] {2442} INFO -  at 267.8s,	estimator lgbm's best error=0.5919,	best estimator lgbm's best error=0.5919
# [flaml.automl.logger: 02-11 15:00:23] {2258} INFO - iteration 68, current learner rf
# [flaml.automl.logger: 02-11 15:00:25] {2442} INFO -  at 269.0s,	estimator rf's best error=0.6369,	best estimator lgbm's best error=0.5919
# [flaml.automl.logger: 02-11 15:00:25] {2258} INFO - iteration 69, current learner rf
# [flaml.automl.logger: 02-11 15:00:26] {2442} INFO -  at 270.8s,	estimator rf's best error=0.6369,	best estimator lgbm's best error=0.5919
# [flaml.automl.logger: 02-11 15:00:26] {2258} INFO - iteration 70, current learner rf
# [flaml.automl.logger: 02-11 15:00:32] {2442} INFO -  at 276.8s,	estimator rf's best error=0.6369,	best estimator lgbm's best error=0.5919
# [flaml.automl.logger: 02-11 15:00:32] {2258} INFO - iteration 71, current learner xgboost
# [flaml.automl.logger: 02-11 15:00:44] {2442} INFO -  at 288.8s,	estimator xgboost's best error=0.7585,	best estimator lgbm's best error=0.5919
# [flaml.automl.logger: 02-11 15:00:44] {2258} INFO - iteration 72, current learner rf
# [flaml.automl.logger: 02-11 15:00:55] {2442} INFO -  at 299.2s,	estimator rf's best error=0.6369,	best estimator lgbm's best error=0.5919
# [flaml.automl.logger: 02-11 15:00:55] {2258} INFO - iteration 73, current learner xgboost
# [flaml.automl.logger: 02-11 15:01:48] {2442} INFO -  at 352.3s,	estimator xgboost's best error=0.7585,	best estimator lgbm's best error=0.5919
# [flaml.automl.logger: 02-11 15:01:48] {2258} INFO - iteration 74, current learner lgbm
# [flaml.automl.logger: 02-11 15:01:54] {2442} INFO -  at 358.6s,	estimator lgbm's best error=0.5919,	best estimator lgbm's best error=0.5919
# [flaml.automl.logger: 02-11 15:01:54] {2258} INFO - iteration 75, current learner lgbm
# [flaml.automl.logger: 02-11 15:02:43] {2442} INFO -  at 407.8s,	estimator lgbm's best error=0.5625,	best estimator lgbm's best error=0.5625
# [flaml.automl.logger: 02-11 15:02:43] {2258} INFO - iteration 76, current learner xgboost
# [flaml.automl.logger: 02-11 15:02:55] {2442} INFO -  at 419.7s,	estimator xgboost's best error=0.7585,	best estimator lgbm's best error=0.5625
# [flaml.automl.logger: 02-11 15:02:55] {2258} INFO - iteration 77, current learner rf
# [flaml.automl.logger: 02-11 15:02:57] {2442} INFO -  at 421.1s,	estimator rf's best error=0.6369,	best estimator lgbm's best error=0.5625
# [flaml.automl.logger: 02-11 15:02:57] {2258} INFO - iteration 78, current learner rf
# [flaml.automl.logger: 02-11 15:03:00] {2442} INFO -  at 424.2s,	estimator rf's best error=0.6369,	best estimator lgbm's best error=0.5625
# [flaml.automl.logger: 02-11 15:03:00] {2258} INFO - iteration 79, current learner xgboost
# [flaml.automl.logger: 02-11 15:03:57] {2442} INFO -  at 481.9s,	estimator xgboost's best error=0.6693,	best estimator lgbm's best error=0.5625
# [flaml.automl.logger: 02-11 15:03:57] {2258} INFO - iteration 80, current learner rf
# [flaml.automl.logger: 02-11 15:04:01] {2442} INFO -  at 485.4s,	estimator rf's best error=0.6173,	best estimator lgbm's best error=0.5625
# [flaml.automl.logger: 02-11 15:04:01] {2258} INFO - iteration 81, current learner rf
# [flaml.automl.logger: 02-11 15:04:10] {2442} INFO -  at 494.2s,	estimator rf's best error=0.4708,	best estimator rf's best error=0.4708
# [flaml.automl.logger: 02-11 15:04:10] {2258} INFO - iteration 82, current learner rf
# [flaml.automl.logger: 02-11 15:04:13] {2442} INFO -  at 497.9s,	estimator rf's best error=0.4708,	best estimator rf's best error=0.4708
# [flaml.automl.logger: 02-11 15:04:13] {2258} INFO - iteration 83, current learner rf
# [flaml.automl.logger: 02-11 15:04:21] {2442} INFO -  at 505.1s,	estimator rf's best error=0.4336,	best estimator rf's best error=0.4336
# [flaml.automl.logger: 02-11 15:04:21] {2258} INFO - iteration 84, current learner rf
# [flaml.automl.logger: 02-11 15:04:30] {2442} INFO -  at 514.1s,	estimator rf's best error=0.4336,	best estimator rf's best error=0.4336
# [flaml.automl.logger: 02-11 15:04:30] {2258} INFO - iteration 85, current learner rf
# [flaml.automl.logger: 02-11 15:04:41] {2442} INFO -  at 525.5s,	estimator rf's best error=0.4336,	best estimator rf's best error=0.4336
# [flaml.automl.logger: 02-11 15:04:41] {2258} INFO - iteration 86, current learner rf
# [flaml.automl.logger: 02-11 15:04:47] {2442} INFO -  at 531.8s,	estimator rf's best error=0.4336,	best estimator rf's best error=0.4336
# [flaml.automl.logger: 02-11 15:04:47] {2258} INFO - iteration 87, current learner rf
# [flaml.automl.logger: 02-11 15:04:55] {2442} INFO -  at 539.6s,	estimator rf's best error=0.4336,	best estimator rf's best error=0.4336
# [flaml.automl.logger: 02-11 15:04:55] {2258} INFO - iteration 88, current learner xgboost
# [flaml.automl.logger: 02-11 15:05:14] {2442} INFO -  at 558.1s,	estimator xgboost's best error=0.6693,	best estimator rf's best error=0.4336
# [flaml.automl.logger: 02-11 15:05:14] {2258} INFO - iteration 89, current learner rf
# [flaml.automl.logger: 02-11 15:05:21] {2442} INFO -  at 565.6s,	estimator rf's best error=0.4121,	best estimator rf's best error=0.4121
# [flaml.automl.logger: 02-11 15:05:21] {2258} INFO - iteration 90, current learner xgboost
# [flaml.automl.logger: 02-11 15:08:39] {2442} INFO -  at 763.6s,	estimator xgboost's best error=0.5649,	best estimator rf's best error=0.4121
# [flaml.automl.logger: 02-11 15:08:39] {2258} INFO - iteration 91, current learner rf
# [flaml.automl.logger: 02-11 15:08:52] {2442} INFO -  at 776.9s,	estimator rf's best error=0.4013,	best estimator rf's best error=0.4013
# [flaml.automl.logger: 02-11 15:08:52] {2258} INFO - iteration 92, current learner rf
# [flaml.automl.logger: 02-11 15:09:03] {2442} INFO -  at 787.1s,	estimator rf's best error=0.4013,	best estimator rf's best error=0.4013
# [flaml.automl.logger: 02-11 15:09:03] {2258} INFO - iteration 93, current learner rf
# [flaml.automl.logger: 02-11 15:09:30] {2442} INFO -  at 814.3s,	estimator rf's best error=0.4013,	best estimator rf's best error=0.4013
# [flaml.automl.logger: 02-11 15:09:30] {2258} INFO - iteration 94, current learner rf
# [flaml.automl.logger: 02-11 15:09:39] {2442} INFO -  at 823.5s,	estimator rf's best error=0.4013,	best estimator rf's best error=0.4013
# [flaml.automl.logger: 02-11 15:09:39] {2258} INFO - iteration 95, current learner rf
# [flaml.automl.logger: 02-11 15:09:44] {2442} INFO -  at 828.9s,	estimator rf's best error=0.4013,	best estimator rf's best error=0.4013
# [flaml.automl.logger: 02-11 15:09:44] {2258} INFO - iteration 96, current learner rf
# [flaml.automl.logger: 02-11 15:10:30] {2442} INFO -  at 874.7s,	estimator rf's best error=0.3910,	best estimator rf's best error=0.3910
# [flaml.automl.logger: 02-11 15:10:30] {2258} INFO - iteration 97, current learner lgbm
# [flaml.automl.logger: 02-11 15:11:22] {2442} INFO -  at 926.5s,	estimator lgbm's best error=0.5409,	best estimator rf's best error=0.3910
# [flaml.automl.logger: 02-11 15:11:22] {2258} INFO - iteration 98, current learner lgbm
# [flaml.automl.logger: 02-11 15:12:11] {2442} INFO -  at 975.8s,	estimator lgbm's best error=0.5409,	best estimator rf's best error=0.3910
# [flaml.automl.logger: 02-11 15:12:11] {2582} INFO - [('rf', {'n_jobs': -1, 'n_estimators': 1590, 'max_features': 0.02850369943975579, 'criterion': 'gini', 'max_leaf_nodes': 7967, 'random_state': 12032022, 'verbose': 0}), ('lgbm', {'n_jobs': -1, 'n_estimators': 271, 'num_leaves': 78, 'min_child_samples': 4, 'learning_rate': 0.03428489064447751, 'colsample_bytree': 0.6695148564302482, 'reg_alpha': 0.02046640007359354, 'reg_lambda': 1.5441186871704737, 'max_bin': 511, 'verbose': -1}), ('xgboost', {'n_jobs': -1, 'n_estimators': 130, 'max_leaves': 69, 'min_child_weight': 0.05827840217309799, 'learning_rate': 0.06967476405828313, 'subsample': 0.8895588746662894, 'colsample_bylevel': 0.5266167196206358, 'colsample_bytree': 0.5793842857429541, 'reg_alpha': 0.044217767103654604, 'reg_lambda': 0.1934396459443843, 'max_depth': 0, 'grow_policy': 'lossguide', 'tree_method': 'hist', 'verbosity': 0})]
# [flaml.automl.logger: 02-11 15:12:11] {2625} INFO - Building ensemble with tuned estimators
# [flaml.automl.logger: 02-11 15:40:10] {2631} INFO - ensemble: StackingClassifier(estimators=[('rf',
#                                 <flaml.automl.model.RandomForestEstimator object at 0x000001D3A002F3B0>),
#                                ('lgbm',
#                                 <flaml.automl.model.LGBMEstimator object at 0x000001D3A002F800>),
#                                ('xgboost',
#                                 <flaml.automl.model.XGBoostSklearnEstimator object at 0x000001D3A002F8F0>)],
#                    n_jobs=1, passthrough=True)
# [flaml.automl.logger: 02-11 15:40:10] {1985} INFO - fit succeeded
# [flaml.automl.logger: 02-11 15:40:10] {1986} INFO - Time taken to find the best model: 874.739914894104
# [flaml.automl.logger: 02-11 15:40:10] {1996} WARNING - Time taken to find the best model is 87% of the provided time budget and not all estimators' hyperparameter search converged. Consider increasing the time budget.
# Training until validation scores don't improve for 10 rounds
# Did not meet early stopping. Best iteration is:
# [3000]	training's multi_logloss: 0.0122583	valid_1's multi_logloss: 1.98422

# %%
# Funktion zur Berechnung der Gesamt-Genauigkeit und Ausgabe der Vorhersagen
def calculate_and_display_accuracy(image_paths, labels, X_test_indices, model, num_examples=10, n_splits=5):
    correct_predictions = 0
    total_images = min(num_examples, len(X_test_indices))
    correct_single_chars = 0
    total_single_chars = 0

    true_and_predicted_labels = []

    for idx in X_test_indices[:total_images]:  # Nur die ersten 10 Beispiele
        image_path = image_paths[idx]
        true_label = labels[idx]
        
        img = preprocess_image(image_path)
        sections = split_image(img, n_splits=n_splits)
        
        predicted_label = ''
        
        for j, section in enumerate(sections):
            section_flat = section.flatten().reshape(1, -1)
            prediction = model.predict(section_flat, num_iteration=model.best_iteration)
            predicted_char = label_encoder.inverse_transform([np.argmax(prediction)])
            predicted_label += predicted_char[0]
            
            # Einzelzeichen-Genauigkeit berechnen
            if predicted_char[0] == true_label[j]:
                correct_single_chars += 1
            total_single_chars += 1
        
        true_and_predicted_labels.append((true_label, predicted_label))

        if predicted_label == true_label:
            correct_predictions += 1
    
    overall_accuracy = correct_predictions / total_images
    single_char_accuracy = correct_single_chars / total_single_chars
    
    # Ausgabe der ersten 10 Gesamt-CAPTCHAs mit Labels und Vorhersagen
    for i in range(total_images):
        true_label, predicted_label = true_and_predicted_labels[i]
        print(f"Beispiel {i+1}:")
        print(f"Tatsächliches Label: {true_label}")
        print(f"Vorhergesagtes Label: {predicted_label}")
        print("-" * 30)
    
    print(f"Gesamt-Genauigkeit (mehrzeichen-CAPTCHA) auf dem Testsatz: {overall_accuracy * 100:.2f}%")
    print(f"Einzelzeichen-Genauigkeit auf dem Testsatz: {single_char_accuracy * 100:.2f}%")

# Gesamt-Genauigkeit und Einzelzeichen-Genauigkeit berechnen und anzeigen
_, X_test_indices = train_test_split(range(len(image_paths)), test_size=0.2, random_state=42)
test_image_paths = [image_paths[i] for i in X_test_indices]  # Wählen Sie die Bilder, die im Testdatensatz enthalten sind
test_labels = [labels[i] for i in X_test_indices]  # Entsprechende Labels

calculate_and_display_accuracy(image_paths, labels, X_test_indices, model, num_examples=10)
# Out:
# Beispiel 1:
# Tatsächliches Label: 0NNTk
# Vorhergesagtes Label: 0NNTk
# ------------------------------
# Beispiel 2:
# Tatsächliches Label: HqHhK
# Vorhergesagtes Label: BqHhK
# ------------------------------
# Beispiel 3:
# Tatsächliches Label: ka2qh
# Vorhergesagtes Label: ka2qh
# ------------------------------
# Beispiel 4:
# Tatsächliches Label: Yy2MK
# Vorhergesagtes Label: Yy2MK
# ------------------------------
# Beispiel 5:
# Tatsächliches Label: YmNt6
# Vorhergesagtes Label: YmCr4
# ------------------------------
# Beispiel 6:
# Tatsächliches Label: XE5fi
# Vorhergesagtes Label: XE5fi
# ------------------------------
# Beispiel 7:
# Tatsächliches Label: 2D2HX
# Vorhergesagtes Label: 2D2HX
# ------------------------------
# Beispiel 8:
# Tatsächliches Label: 7576k
# Vorhergesagtes Label: 5576K
# ------------------------------
# Beispiel 9:
# Tatsächliches Label: WYaHq
# Vorhergesagtes Label: WYrHq
# ------------------------------
# Beispiel 10:
# Tatsächliches Label: aq3yC
# Vorhergesagtes Label: aq3yC
# ------------------------------
# Gesamt-Genauigkeit (mehrzeichen-CAPTCHA) auf dem Testsatz: 60.00%
# Einzelzeichen-Genauigkeit auf dem Testsatz: 86.00%
